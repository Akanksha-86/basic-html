# %% [markdown]
# # Tailwind CSS

# %% [markdown]
# * Note - all the assignments should be done using Tailwind CSS, set-up using Vite *
#
# Task 1: User Login page
#
# Problem statement -
#
# Create a User login page interface that closely resembles the provided image using Tailwind CSS. The goal is
# to ensure that your implementation captures every visual detail and layout aspect depicted in the image while
# maintaining a full mobile responsiveness.
#
#
# Get the image from (https://www.freepik.com/free-photo/young-happy-woman-with-good-idea-signwhite-shirt-fullportrait_10881326.htm#page=2&query=login&position=11&from_view=search&track=sph)
#
# large screen (minimum width of 1024px)
#
# ![image.png](data:image/png;base64,...)
#
# Small screen (minimum width of 640px)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
/* Html code */
<!DOCTYPE html>
<html lang="en" class="scroll-smooth">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Login - Your App</title>
  <script type="module" crossorigin src="/src/main.js"></script>
  <link rel="stylesheet" href="/src/style.css">
</head>
<body class="bg-gradient-to-br from-slate-50 via-blue-50 to-indigo-100 min-h-screen">

  <!-- Background Pattern -->
  <div class="fixed inset-0 overflow-hidden pointer-events-none">
    <div class="absolute -top-40 -right-40 w-80 h-80 bg-primary-500/5 rounded-full blur-3xl"></div>
    <div class="absolute -bottom-40 -left-40 w-80 h-80 bg-indigo-500/5 rounded-full blur-3xl"></div>
  </div>

  <div class="min-h-screen flex flex-col sm:flex-row items-center justify-center p-4 sm:p-8 lg:p-12">

    <!-- Left Side - Illustration/Image Area -->
    <div class="w-full sm:w-1/2 lg:w-2/5 mb-8 sm:mb-0 sm:mr-8 lg:mr-12 flex flex-col items-center justify-center">
      <!-- Logo/Icon -->
      <div class="w-24 h-24 bg-gradient-to-br from-primary-500 to-indigo-600 rounded-2xl flex items-center justify-center shadow-2xl mb-6">
        <svg class="w-12 h-12 text-white" fill="none" stroke="currentColor" viewBox="0 0 24 24">
          <path stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5" d="M19 11H5m14 0a2 2 0 012 2v6a2 2 0 01-2 2H5a2 2 0 01-2-2v-6a2 2 0 012-2m14 0V9a2 2 0 00-2-2M5 11V9a2 2 0 012-2m0 0V5a2 2 0 012-2h6a2 2 0 012 2v2M7 7h10" />
        </svg>
      </div>

      <!-- Welcome Text -->
      <div class="text-center max-w-md">
        <h1 class="text-4xl sm:text-5xl lg:text-6xl font-black bg-gradient-to-r from-gray-900 via-gray-700 to-slate-900 bg-clip-text text-transparent mb-4 leading-tight">
          Welcome Back
        </h1>
        <p class="text-xl sm:text-2xl text-gray-600 font-medium leading-relaxed">
          Sign in to continue to your account
        </p>
      </div>

      <!-- Decorative Elements -->
      <div class="mt-12 space-y-4 opacity-60">
        <div class="w-24 h-1 bg-gradient-to-r from-primary-500 to-indigo-500 rounded-full mx-auto"></div>
        <div class="text-sm text-gray-500 text-center">Trusted by 50K+ users</div>
      </div>
    </div>

    <!-- Right Side - Login Form -->
    <div class="w-full sm:w-1/2 lg:w-3/5 max-w-md">
      <div class="bg-white/80 backdrop-blur-xl rounded-3xl p-8 sm:p-10 lg:p-12 shadow-2xl border border-white/50">

        <!-- Form Header -->
        <div class="mb-8 text-center">
          <h2 class="text-3xl sm:text-4xl font-bold text-gray-900 mb-2">Sign In</h2>
          <p class="text-gray-600 text-lg">Enter your credentials below</p>
        </div>

        <!-- Login Form -->
        <form class="space-y-6">

          <!-- Email Input -->
          <div>
            <label class="block text-sm font-semibold text-gray-700 mb-3">Email Address</label>
            <div class="relative">
              <div class="absolute inset-y-0 left-0 pl-4 flex items-center pointer-events-none">
                <svg class="w-5 h-5 text-gray-400" fill="none" stroke="currentColor" viewBox="0 0 24 24">
                  <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M16 12a4 4 0 10-8 0 4 4 0 008 0zm0 0v1.5a2.5 2.5 0 005 0V12a9 9 0 10-9 9m4.5-1.206a8.959 8.959 0 01-4.5 1.207"></path>
                </svg>
              </div>
              <input
                type="email"
                required
                placeholder="your@email.com"
                class="input-field pl-12 pr-4"
              />
            </div>
          </div>

          <!-- Password Input -->
          <div>
            <label class="block text-sm font-semibold text-gray-700 mb-3">Password</label>
            <div class="relative">
              <div class="absolute inset-y-0 left-0 pl-4 flex items-center pointer-events-none">
                <svg class="w-5 h-5 text-gray-400" fill="none" stroke="currentColor" viewBox="0 0 24 24">
                  <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M12 15v2m-6 4h12a2 2 0 002-2v-6a2 2 0 00-2-2H6a2 2 0 00-2 2v6a2 2 0 002 2zm10-10V7a4 4 0 00-8 0v4h8z"></path>
                </svg>
              </div>
              <input
                type="password"
                required
                placeholder="••••••••"
                class="input-field pl-12 pr-4"
              />
            </div>
          </div>

          <!-- Remember & Forgot Password -->
          <div class="flex items-center justify-between flex-wrap gap-4">
            <label class="flex items-center text-sm">
              <input type="checkbox" class="w-5 h-5 text-primary-600 rounded border-gray-300 focus:ring-primary-500">
              <span class="ml-2 text-gray-700 font-medium">Remember me</span>
            </label>
            <a href="#" class="text-sm font-semibold text-primary-600 hover:text-primary-700 transition-colors">Forgot Password?</a>
          </div>

          <!-- Sign In Button -->
          <button type="submit" class="btn-primary">
            <span class="flex items-center">
              <svg class="w-5 h-5 mr-2" fill="none" stroke="currentColor" viewBox="0 0 24 24">
                <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M11 16l-4-4m0 0l4-4m-4 4h14m-5 4v1a3 3 0 01-3 3H6a3 3 0 01-3-3V7a3 3 0 013-3h7a3 3 0 013 3v1"></path>
              </svg>
              Sign In
            </span>
          </button>

          <!-- Divider -->
          <div class="relative flex items-center py-4">
            <div class="flex-grow border-t border-gray-200"></div>
            <span class="flex-shrink mx-4 text-gray-400 font-medium">or continue with</span>
            <div class="flex-grow border-t border-gray-200"></div>
          </div>

          <!-- Social Login -->
          <div class="grid gap-3">
            <button class="w-full flex items-center justify-center px-6 py-3 border border-gray-200 rounded-xl hover:bg-gray-50 hover:shadow-md transition-all duration-200 text-gray-700 font-medium">
              <svg class="w-5 h-5 mr-2" viewBox="0 0 24 24">
                <path fill="#4285F4" d="M22.56 12.25c0-.78-.07-1.53-.2-2.25H12v4.26h5.92c-.26 1.37-1.04 2.53-2.21 3.31v2.77h3.57c2.08-1.92 3.28-4.74 3.28-8.09z"/>
                <!-- Simplified Google icon -->
              </svg>
              Continue with Google
            </button>

            <button class="w-full flex items-center justify-center px-6 py-3 border border-gray-200 rounded-xl hover:bg-gray-50 hover:shadow-md transition-all duration-200 text-gray-700 font-medium">
              <svg class="w-5 h-5 mr-2" fill="currentColor" viewBox="0 0 24 24">
                <path d="M18.92 6.02C18.72 4.42 17.88 3.13 16.73 2.3c-.12-.07-.25-.12-.38-.17a9.39 9.39 0 00-2.08-.44c-.52-.06-1.05-.1-1.58-.12-.53-.02-1.06-.02-1.59 0-.53.02-1.06.07-1.59.14a9.69 9.69 0 00-2.08.45c-.13.05-.26.1-.38.17-1.15.83-2 2.12-2.19 3.72-.08.52-.13 1.04-.15 1.57-.02.53-.02 1.06 0 1.59.02.53.07 1.06.15 1.58.19 1.6.99 3.24 2.19 4.04 1.15.83 2 2.12 2.19 3.72.08.52.13 1.04.15 1.57.02.53.02 1.06 0 1.59-.02.53-.07 1.06-.15 1.58-.19 1.6-.99 3.24-2.19 4.04-1.15.83-2 2.12-2.19 3.72-.08.52-.13 1.04-.15 1.57-.02.53-.02 1.06 0 1.59.02.53.07 1.06.15 1.58.19 1.6.99 3.24 2.19 4.04 1.15.83 2 2.12 2.19 3.72.08.52.13 1.04.15 1.57.02.53.02 1.06 0 1.59-.02.53-.07 1.06-.15 1.58-.19 1.6-.99 3.24-2.19 4.04-1.15.83-2 2.12-2.19 3.72-.08.52-.13 1.04-.15 1.57-.02.53-.02 1.06 0 1.59.02.53.07 1.06.15 1.58.19 1.6.99 3.24 2.19 4.04 1.15.83 2 2.12 2.19 3.72.08.52.13 1.04.15 1.57.02.53.02 1.06 0 1.59-.02.53-.07 1.06-.15 1.58-.19 1.6-.99 3.24-2.19 4.04-1.15.83-2 2.12-2.19 3.72-.08.52-.13 1.04-.15 1.57-.02.53-.02 1.06 0 1.59.02.53.07 1.06.15 1.58.19 1.6.99 3.24 2.19 4.04 1.15.83 2 2.12 2.19 3.72.08.52.13 1.04.15 1.57.02.53.02 1.06 0 1.59-.02.53-.07 1.06-.

        /* css code */
        @tailwind base;
@tailwind components;
@tailwind utilities;

@layer components {
  .input-field {
    @apply w-full px-4 py-3 rounded-xl border border-gray-200 bg-white/50 backdrop-blur-sm
           focus:outline-none focus:ring-2 focus:ring-primary-500 focus:border-transparent
           transition-all duration-200 hover:shadow-lg;
  }

  .btn-primary {
    @apply w-full py-3 px-6 rounded-xl font-semibold text-white bg-gradient-to-r
           from-primary-600 to-primary-700 hover:from-primary-700 hover:to-primary-800
           focus:outline-none focus:ring-4 focus:ring-primary-500/50 shadow-xl
           hover:shadow-2xl transform hover:-translate-y-0.5 transition-all duration-200;
  }
}

/* JS code */
/** @type {import('tailwindcss').Config} */
export default {
  content: [
    "./index.html",
    "./src/**/*.{js,ts,jsx,tsx}",
  ],
  theme: {
    extend: {
      colors: {
        primary: {
          50: '#eff6ff',
          500: '#3b82f6',
          600: '#2563eb',
          700: '#1d4ed8',
        }
      }
    },
  },
  plugins: [],
}

# %% [markdown]
# Task 2:  Image gallery
#
#
#
# Problem statement -
#
# Create a responsive image gallery using Tailwind CSS. The gallery should display a grid of images that adjust
# their size and layout based on the screen size.
#
# Expected output -
#
# large screen (minimum width of 1024px)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
/* Html code */
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Responsive Image Gallery</title>
  <script type="module" crossorigin src="/src/main.js"></script>
  <link rel="stylesheet" href="/src/style.css">
</head>
<body class="bg-gradient-to-br from-slate-900 via-purple-900/30 to-slate-900 min-h-screen overflow-x-hidden">

  <!-- Header -->
  <header class="text-center py-16 px-4">
    <h1 class="text-5xl md:text-7xl lg:text-8xl font-black bg-gradient-to-r from-white via-slate-200 to-slate-400 bg-clip-text text-transparent mb-6 animate-fade-in">
      Image Gallery
    </h1>
    <p class="text-xl md:text-2xl text-slate-300 max-w-2xl mx-auto leading-relaxed">
      Responsive grid layout that adapts perfectly across all devices
    </p>
  </header>

  <!-- Gallery Container -->
  <main class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8 pb-16">

    <!-- Gallery Grid - Responsive Breakpoints -->
    <div class="grid grid-cols-1 sm:grid-cols-2 lg:grid-cols-3 xl:grid-cols-4 2xl:grid-cols-5
                gap-6 sm:gap-8 lg:gap-10 xl:gap-12 auto-rows-[1px] animate-slide-up">

      <!-- Image 1 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1677442136019-21780ecad995?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="Nature Landscape"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Mountain Peak</h3>
            <p class="text-sm opacity-90">Nature Photography</p>
          </div>
        </div>
      </figure>

      <!-- Image 2 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1506905925346-21bda4d32df4?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="City Skyline"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Urban Lights</h3>
            <p class="text-sm opacity-90">Cityscape</p>
          </div>
        </div>
      </figure>

      <!-- Image 3 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1551632811-561732d1e306?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="Portrait"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Portrait</h3>
            <p class="text-sm opacity-90">People</p>
          </div>
        </div>
      </figure>

      <!-- Image 4 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1441974231531-c6227db76b6e?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="Food"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Gourmet Dish</h3>
            <p class="text-sm opacity-90">Food Photography</p>
          </div>
        </div>
      </figure>

      <!-- Image 5 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1506905925346-21bda4d32df4?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="Ocean Waves"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Ocean Waves</h3>
            <p class="text-sm opacity-90">Seascape</p>
          </div>
        </div>
      </figure>

      <!-- Image 6 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1551632811-561732d1e306?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="Forest Path"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Forest Path</h3>
            <p class="text-sm opacity-90">Nature Trail</p>
          </div>
        </div>
      </figure>

      <!-- Image 7 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1677442136019-21780ecad995?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="Sunset Beach"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Sunset Beach</h3>
            <p class="text-sm opacity-90">Golden Hour</p>
          </div>
        </div>
      </figure>

      <!-- Image 8 -->
      <figure class="group relative overflow-hidden rounded-2xl shadow-2xl hover:shadow-3xl transition-all duration-500">
        <img src="https://images.unsplash.com/photo-1441974231531-c6227db76b6e?ixlib=rb-4.0.3&auto=format&fit=crop&w=1000&q=80"
             alt="Architecture"
             class="gallery-img"
             loading="lazy"
        />
        <div class="gallery-overlay">
          <div class="text-white">
            <h3 class="text-xl font-bold mb-1">Modern Architecture</h3>
            <p class="text-sm opacity-90">Building Design</p>
          </div>
        </div>
      </figure>

    </div>

    <!-- Load More Button -->
    <div class="text-center mt-16">
      <button class="px-12 py-4 bg-white/20 backdrop-blur-sm text-white font-semibold text-lg rounded-2xl
                     border-2 border-white/30 hover:bg-white/30 hover:border-white/50
                     transition-all duration-300 hover:scale-105 shadow-2xl hover:shadow-3xl">
        Load More Images
      </button>
    </div>

  </main>

  <!-- Footer -->
  <footer class="text-center py-12 text-slate-400 text-sm border-t border-slate-800">
    <p>Built with ❤️ using Tailwind CSS • Responsive across all devices</p>
  </footer>

</body>
</html>

/* css code */

@tailwind base;
@tailwind components;
@tailwind utilities;

@layer components {
  .gallery-img {
    @apply w-full h-64 sm:h-80 md:h-96 lg:h-[450px] object-cover rounded-2xl shadow-xl hover:shadow-2xl transition-all duration-500 hover:scale-105 hover:-translate-y-2 cursor-pointer group;
  }

  .gallery-overlay {
    @apply absolute inset-0 bg-gradient-to-t from-black/60 via-transparent to-transparent opacity-0 group-hover:opacity-100 transition-all duration-500 flex items-end p-6 rounded-2xl;
  }
}

/* js code */
/** @type {import('tailwindcss').Config} */
export default {
  content: ["./index.html", "./src/**/*.{js,ts,jsx,tsx}"],
  theme: {
    extend: {
      animation: {
        'fade-in': 'fadeIn 0.5s ease-in-out',
        'slide-up': 'slideUp 0.6s ease-out',
      },
      keyframes: {
        fadeIn: {
          '0%': { opacity: '0' },
          '100%': { opacity: '1' },
        },
        slideUp: {
          '0%': { transform: 'translateY(20px)', opacity: '0' },
          '100%': { transform: 'translateY(0)', opacity: '1' },
        }
      }
    },
  },
  plugins: [],
}

# %% [markdown]
# Task 3: Dashboard
#
# Problem statement -
#
# Create a non-responsive dashboard using Tailwind CSS, where the dashboard should include a sidebar
# navigation menu and a main contain area. (Making it responsive is optional).
#
# Feel free to use any icons from any place, Your goal is to design a visually appealing and user-friendly
# dashboard interface that is not responsive
#
# ![image.png](data:image/png;base64,...)

# %%
/* Html */
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Admin Dashboard</title>
  <script type="module" crossorigin src="/src/main.js"></script>
  <link rel="stylesheet" href="/src/style.css">
  <!-- Heroicons CDN for icons -->
  <script src="https://cdn.tailwindcss.com"></script>
  <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
</head>
<body class="bg-gradient-to-br from-slate-900 via-purple-900/20 to-slate-900 min-h-screen text-white overflow-hidden">

  <div class="flex h-screen">

    <!-- Sidebar Navigation -->
    <aside class="w-80 bg-white/10 backdrop-blur-xl border-r border-white/20 shadow-2xl">
      <div class="p-8 border-b border-white/10">
        <div class="flex items-center space-x-3">
          <div class="w-12 h-12 bg-gradient-to-r from-primary-500 to-indigo-600 rounded-2xl flex items-center justify-center shadow-xl">
            <i class="fas fa-chart-line text-2xl text-white"></i>
          </div>
          <div>
            <h1 class="text-2xl font-black bg-gradient-to-r from-white to-slate-200 bg-clip-text text-transparent">Dashboard</h1>
            <p class="text-sm text-slate-400">Admin Panel</p>
          </div>
        </div>
      </div>

      <!-- Navigation Menu -->
      <nav class="mt-8 px-4 space-y-2">
        <a href="#" class="sidebar-link-active">
          <i class="fas fa-house w-6 mr-4"></i>
          Dashboard
        </a>
        <a href="#" class="sidebar-link">
          <i class="fas fa-users w-6 mr-4"></i>
          Users
        </a>
        <a href="#" class="sidebar-link">
          <i class="fas fa-shopping-cart w-6 mr-4"></i>
          Orders
        </a>
        <a href="#" class="sidebar-link">
          <i class="fas fa-chart-bar w-6 mr-4"></i>
          Analytics
        </a>
        <a href="#" class="sidebar-link">
          <i class="fas fa-cog w-6 mr-4"></i>
          Settings
        </a>
        <a href="#" class="sidebar-link">
          <i class="fas fa-envelope w-6 mr-4"></i>
          Messages
        </a>
        <a href="#" class="sidebar-link">
          <i class="fas fa-file-invoice w-6 mr-4"></i>
          Reports
        </a>
      </nav>

      <!-- User Profile -->
      <div class="absolute bottom-8 left-8 right-8 p-6 bg-white/20 backdrop-blur-xl rounded-2xl border border-white/30">
        <div class="flex items-center space-x-4">
          <div class="w-14 h-14 bg-gradient-to-r from-orange-400 to-pink-500 rounded-2xl flex items-center justify-center shadow-lg">
            <i class="fas fa-user text-2xl text-white"></i>
          </div>
          <div>
            <h3 class="font-bold text-lg">John Doe</h3>
            <p class="text-sm text-slate-400">Administrator</p>
          </div>
        </div>
        <a href="#" class="mt-3 block text-center text-sm font-medium text-slate-300 hover:text-white transition-colors">Sign out</a>
      </div>
    </aside>

    <!-- Main Content Area -->
    <div class="flex-1 flex flex-col overflow-hidden">

      <!-- Top Header -->
      <header class="bg-white/10 backdrop-blur-xl border-b border-white/20 shadow-lg px-8 py-6">
        <div class="flex items-center justify-between">
          <div>
            <h2 class="text-4xl font-black bg-gradient-to-r from-white to-slate-200 bg-clip-text text-transparent">
              Dashboard Overview
            </h2>
            <p class="text-slate-400 mt-1">Welcome back, John! Here's what's happening with your business today.</p>
          </div>
          <div class="flex items-center space-x-4">
            <div class="relative">
              <i class="fas fa-bell text-xl text-slate-400 cursor-pointer hover:text-white transition-colors p-2"></i>
              <span class="absolute -top-2 -right-2 w-6 h-6 bg-red-500 text-xs rounded-full flex items-center justify-center font-bold">3</span>
            </div>
            <div class="w-10 h-10 bg-gradient-to-r from-purple-500 to-pink-500 rounded-2xl flex items-center justify-center cursor-pointer shadow-lg hover:shadow-xl transition-all"></div>
          </div>
        </div>
      </header>

      <!-- Main Dashboard Content -->
      <main class="flex-1 p-8 overflow-y-auto space-y-8">

        <!-- Stats Cards Row -->
        <div class="grid grid-cols-4 gap-8 mb-12">

          <!-- Total Users -->
          <div class="stat-card">
            <div class="flex items-center justify-between mb-6">
              <div class="w-16 h-16 bg-gradient-to-br from-emerald-400 to-teal-500 rounded-2xl flex items-center justify-center shadow-xl">
                <i class="fas fa-users text-2xl text-white"></i>
              </div>
              <div class="p-3 bg-emerald-500/20 rounded-xl">
                <i class="fas fa-arrow-up text-emerald-400 text-xl"></i>
              </div>
            </div>
            <div>
              <p class="text-4xl font-black text-gray-900 mb-1">12,456</p>
              <p class="text-gray-600 font-semibold text-lg">Total Users</p>
              <p class="text-sm text-emerald-600 font-medium mt-1">+12% from last month</p>
            </div>
          </div>

          <!-- Revenue -->
          <div class="stat-card">
            <div class="flex items-center justify-between mb-6">
              <div class="w-16 h-16 bg-gradient-to-br from-blue-500 to-indigo-600 rounded-2xl flex items-center justify-center shadow-xl">
                <i class="fas fa-dollar-sign text-2xl text-white"></i>
              </div>
              <div class="p-3 bg-blue-500/20 rounded-xl">
                <i class="fas fa-arrow-up text-blue-400 text-xl"></i>
              </div>
            </div>
            <div>
              <p class="text-4xl font-black text-gray-900 mb-1">$245,678</p>
              <p class="text-gray-600 font-semibold text-lg">Revenue</p>
              <p class="text-sm text-blue-600 font-medium mt-1">+28% growth</p>
            </div>
          </div>

          <!-- Orders -->
          <div class="stat-card">
            <div class="flex items-center justify-between mb-6">
              <div class="w-16 h-16 bg-gradient-to-br from-purple-500 to-violet-600 rounded-2xl flex items-center justify-center shadow-xl">
                <i class="fas fa-shopping-cart text-2xl text-white"></i>
              </div>
              <div class="p-3 bg-purple-500/20 rounded-xl">
                <i class="fas fa-arrow-down text-purple-400 text-xl"></i>
              </div>
            </div>
            <div>
              <p class="text-4xl font-black text-gray-900 mb-1">1,234</p>
              <p class="text-gray-600 font-semibold text-lg">Orders</p>
              <p class="text-sm text-purple-600 font-medium mt-1">-3% from last week</p>
            </div>
          </div>

          <!-- Conversion Rate -->
          <div class="stat-card">
            <div class="flex items-center justify-between mb-6">
              <div class="w-16 h-16 bg-gradient-to-br from-amber-500 to-orange-500 rounded-2xl flex items-center justify-center shadow-xl">
                <i class="fas fa-chart-pie text-2xl text-white"></i>
              </div>
              <div class="p-3 bg-amber-500/20 rounded-xl">
                <i class="fas fa-arrow-up text-amber-400 text-xl"></i>
              </div>
            </div>
            <div>
              <p class="text-4xl font-black text-gray-900 mb-1">4.2%</p>
              <p class="text-gray-600 font-semibold text-lg">Conversion</p>
              <p class="text-sm text-amber-600 font-medium mt-1">+1.8% improvement</p>
            </div>
          </div>

        </div>

        <!-- Charts & Tables Row -->
        <div class="grid grid-cols-3 gap-8">

          <!-- Revenue Chart -->
          <div class="stat-card col-span-2 h-96">
            <div class="flex items-center justify-between mb-6">
              <h3 class="text-2xl font-bold text-gray-900">Revenue Chart</h3>
              <div class="flex items-center space-x-4 text-sm">
                <span class="flex items-center text-green-600"><i class="fas fa-circle mr-2 text-xs"></i>Revenue</span>
                <span class="flex items-center text-blue-600"><i class="fas fa-circle mr-2 text-xs"></i>Target</span>
              </div>
            </div>
            <div class="h-72 bg-gradient-to-r from-slate-100 to-slate-200 rounded-2xl animate-pulse"></div>
          </div>

          <!-- Quick Actions -->
          <div class="stat-card space-y-4">
            <h3 class="text-2xl font-bold text-gray-900">Quick Actions</h3>
            <div class="space-y-3">
              <button class="w-full flex items-center p-4 bg-gradient-to-r from-emerald-500 to-teal-600 text-white rounded-xl hover:from-emerald-600 hover:to-teal-700 shadow-lg transition-all duration-200">
                <i class="fas fa-plus mr-3"></i>New User
              </button>
              <button class="w-full flex items-center p-4 bg-gradient-to-r from-blue-500 to-indigo-600 text-white rounded-xl hover:from-blue-600 hover:to-indigo-700 shadow-lg transition-all duration-200">
                <i class="fas fa-file-export mr-3"></i>Export Data
              </button>
              <button class="w-full flex items-center p-4 bg-gradient-to-r from-purple-500 to-violet-600 text-white rounded-xl hover:from-purple-600 hover:to-violet-700 shadow-lg transition-all duration-200">
                <i class="fas fa-cog mr-3"></i>Settings
              </button>
            </div>
          </div>

        </div>

        <!-- Recent Activity Table -->
        <div class="stat-card">
          <h3 class="text-2xl font-bold text-gray-900 mb-6">Recent Activity</h3>
          <div class="overflow-x-auto">
            <table class="w-full text-sm">
              <thead>
                <tr class="border-b border-gray-200">
                  <th class="text-left py-4 font-semibold text-gray-700">User</th>
                  <th class="text-left py-4 font-semibold text-gray-700">Action</th>
                  <th class="text-left py-4 font-semibold text-gray-700">Date</th>
                  <th class="text-left py-4 font-semibold text-gray-700">Status</th>
                </tr>
              </thead>
              <tbody class="divide-y divide-gray-200">
                <tr class="hover:bg-gray-50 transition-colors">
                  <td class="py-4">
                    <div class="flex items-center">
                      <div class="w-10 h-10 bg-blue-500 rounded-xl flex items-center justify-center text-white font-bold mr-3">JD</div>
                      <span>John Doe</span>
                    </div>
                  </td>
                  <td class="py-4 text-gray-700">New Order #1234</td>
                  <td class="py-4 text-gray-700">2 min ago</td>
                  <td><span class="px-3 py-1 bg-emerald-100 text-emerald-800 rounded-full text-xs font-medium">Completed</span></td>
                </tr>
                <!-- More rows... -->
              </tbody>
            </table>
          </div>
        </div>

      </main>
    </div>
  </div>

</body>
</html>

/* css code */
@tailwind base;
@tailwind components;
@tailwind utilities;

@layer components {
  .sidebar-link {
    @apply flex items-center px-6 py-4 text-gray-700 hover:bg-primary-50 hover:text-primary-700 transition-all duration-200 rounded-xl font-medium;
  }

  .sidebar-link-active {
    @apply bg-gradient-to-r from-primary-500 to-primary-600 text-white shadow-lg;
  }

  .stat-card {
    @apply bg-white/80 backdrop-blur-xl rounded-3xl p-8 shadow-2xl border border-white/50 hover:shadow-3xl transition-all duration-300 hover:-translate-y-2;
  }
}

/* js code */
/** @type {import('tailwindcss').Config} */
export default {
  content: ["./index.html", "./src/**/*.{js,ts,jsx,tsx}"],
  theme: {
    extend: {
      colors: {
        primary: {
          50: '#eff6ff',
          500: '#3b82f6',
          600: '#2563eb',
          700: '#1d4ed8',
          900: '#1e3a8a',
        }
      },
      animation: {
        'pulse-slow': 'pulse 3s infinite',
      }
    },
  },
  plugins: [],
}
