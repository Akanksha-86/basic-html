# %% [markdown]
# # More on CSS

# %% [markdown]
# 1. create a nevigation bar similar to the below-mentioned image. the nevigation bar must be contain 5 nevigation link that are the properly placed with in the nevigation bar using the css box models. the nevigation item must change their color on hover.
# ![image.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>nevigation bar</title>
    <style>
    <body>
      margin:0;
    font-family: Arial, Hevetica, sans-serif;
    </body>

    .topnav{
     overflow: hidden;
      backgroumd-color: blue;

}
.topnav a {
 float: left;
 color: white;
 text-decoration: center;
 padding: 14px 27px;
 text-decoration: none;
 font-size: 17px;
 background-color: blue;
}
.topnav a:hover {
  background-color: blue;
  color: blueviolet;
}
  </style>
</head>
<body>
<div class="topnav">
<a class="active"
href="#home"><ins>Home</ins></a>
<a href="#About Us"><ins>About Us</ins></a>
<a href="#Contect"><ins>Contect</ins></a>
<a href="#Blog"><ins>Blog</ins></a>
<a href="#Login"><ins>Login</ins></a>
</div>

</body>
</html>

# %% [markdown]
# 2. create a div centered with an image and paragraph similar to the image mentioned below.
#
# ![image.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Full Stack Web Development</title>
    <style>
        body {
            font-family: sans-serif;
            margin: 0;
            padding: 0;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh;
            background-color: #f0f0f0;
        }
        .container {
            background-color: #e0dada;
            padding: 20px;
            border-radius: 4px;
            box-shadow: 0 0 10px rgba(0,0,0,0.1);
            text-align: center;
        }
        .header {
            background-color: rgba(250, 250, 6, 0.993);
            color: white;
            padding: 10px;
            border-radius: 0 0 0 0;
            margin-left: 20px;
            margin-right:20px;
        }
        .content {
            padding: 10px;
        }

        p {
            margin-bottom: 0px;
            color: black;
        }
        .images {
            display: flex;
            justify-content: center;
            margin-top: 10px;
        }
        .images img {
            width: 200px;
            height: 100px;
            border-radius: 20px;
            margin:  10px;
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="header">
            <img src="pw image.jpg"
        </div>
        <div class="content">
            <p><b> Course Name:</b> PW SKILLS Full stack web development</p>
        </div>

    </div>
</body>
</html>

# %% [markdown]
# 3. create a nevigation bar similar to question 1. for each nevigation item, use border style.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>nevigation bar</title>
    <style>
    <body>
      margin:0;
    </body>
    main{
      margin-left: 20px;
      margin-right: 20px;
    }
    h1 {
      text-align: center;
    }

    .navbar ul {
     list-style-type: none;
      backgroumd-color: blue;
     padding: 0px;
     margin: 0px;
     overflow: hidden;
}
.navbar a {

 color: white;
 text-decoration: center;
 padding: 14px 27px;
 text-decoration: none;
 display: block;
 font-size: 17px;
 background-color: rgb(40, 40, 133);
}
.navbar a:hover {
  background-color: blue;
  color: blueviolet;
}
.navbar li {
float: left;
}

  </style>
</head>
<body>
<nav class="navbar">
    <ul>
<li><a href="home.html"><ins>Home</ins></a></li>
<li><a href="about us.html"><ins>About Us</ins></a></li>
<li><a href="contect.html"><ins>Contect</ins></a></li>
<li><a href="blog.html"><ins>Blog</ins></a></li>
<li><a href="login.html"><ins>Login</ins></a></li>
</ul>
</nav>
<main>

    <h2>This is a home page</h2>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Tempore delectus laborum quasi eos quas perferendis quos repudiandae, est amet libero, doloribus, eaque tenetur ad quibusdam iure veritatis voluptatum ipsa aperiam.</p>
    </main>
</body>
</html>

# %% [markdown]
# 4. create a simple webpage with an image and make the image circular using border-redius.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1" />
  <title>Circular Image Example</title>
  <style>
    body {
      display: flex;
      justify-content: center;
      align-items: center;
      min-height: 100vh;
      margin: 0;
      background-color: #f5f5f5;
      font-family: Arial, sans-serif;
    }
    .circular-image {
      width: 200px;
      height: 200px;
      border-radius: 50%;
      object-fit: cover;
      box-shadow: 0 4px 15px rgba(0,0,0,0.1);
    }
  </style>
</head>
<body>
  <img
    src="images/about-img-2.jpg"
    alt="Circular styled placeholder image with blue background and white text"
    class="circular-image"
  />
</body>
</html>

# %% [markdown]
# 5. create a simple blog webside about google fonts. the webpage must havr the heading with "oswald" font align center tp the page, below the hreading have an image of goolgle fonts and a paragraph aboutr google fonts in font "Montserrat" paragraph font style should be  "Montserrat" font.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1" />
  <title>Google Fonts Blog</title>
  <!-- Google Fonts -->
  <link rel="preconnect" href="https://fonts.googleapis.com" />
  <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin />
  <link
    href="https://fonts.googleapis.com/css2?family=Montserrat&family=Oswald:wght@700&display=swap"
    rel="stylesheet"
  />
  <style>
    /* Reset and base styles */
    *, *::before, *::after {
      box-sizing: border-box;
    }
    body {
      margin: 0;
      background-color: #ffffff;
      color: #6b7280; /* neutral gray for paragraph */
      font-family: 'Montserrat', sans-serif;
      line-height: 1.6;
      padding: 48px 16px;
      display: flex;
      justify-content: center;
      align-items: flex-start;
      min-height: 100vh;
    }
    .container {
      max-width: 720px;
      width: 100%;
      display: flex;
      flex-direction: column;
      align-items: center;
      gap: 32px;
    }
    h1 {
      font-family: 'Oswald', sans-serif;
      font-weight: 700;
      font-size: 48px;
      margin: 0;
      color: #111827; /* dark gray/black */
      text-align: center;
    }
    img {
      width: 100%;
      max-width: 480px;
      border-radius: 12px;
      box-shadow: 0 8px 16px rgba(0,0,0,0.1);
      object-fit: contain;
    }
    p {
      font-size: 18px;
      font-weight: 400;
      max-width: 600px;
      text-align: center;
      margin: 0;
      color: #4b5563; /* slightly darker gray for better readability */
    }
  </style>
</head>
<body>
  <main class="container" role="main">
    <h1>Google Fonts</h1>
    <img
      src="https://storage.googleapis.com/workspace-0f70711f-8b4e-4d94-86f1-2a93ccde5887/image/1f4be593-4d1f-447b-b175-2bed2cbbc81f.png"
      alt="Stylized Google Fonts logo with colorful letter icons on a blue background"
      width="480" height="260"
      loading="lazy"
    />
    <p>
      Google Fonts is a rich library of open-source fonts optimized for the web. It allows developers and designers to easily embed high-quality typography into their projects, improving readability and aesthetic appeal across devices and screen sizes.
    </p>
  </main>
</body>
</html>

# %% [markdown]
# 6. create a simple webside as mentioned in the below image. you can get the assets by visiting https://pwskills.com/about-us .
#
# ![image.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>About us</title>
    <style>
        h1 {
            text-align: center;
        }
        div {
        text-align: center;

        }
    </style>
</head>
<body>
    <h1>About Us</h1>
    <p>PW skills' mission is to permeate through every student/professional's outlook toward jobs and change their attitude and perspective from "how can i do it?" to "Of Course i can do it".We aim to do this b y providing expectional up skilling course at affordable rates, while being teach-forward so anyone, anywhere can access the improve their ability to be successful in life. </p>
   <div class="image">
    <img src="pw about.jpg">
    </div>
</body>
</html>

# %% [markdown]
# 7. create a simple webpage with a card similar question number 2. the card must be semi-transparent as default and on hovering the card must be displayed clearly. use css apecity to achive this output.
#
# ![image.png](data:image/png;base64,...)

# %%
<!--without hover-->

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Web Development Course</title>
    <style>
        body {
            font-family: sans-serif;
            margin: 0;
            padding: 0;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh;
            background-color: #f0f0f0;
        }
        .container {
            background-color: #e0d7d7;
            border-radius: 20px;
            box-shadow: 0 10px 10px rgba(0,0,0,0.1);
            overflow: hidden;
            width: 80%;
            max-width: 700px;
        }
        .image-container {
            position: relative;
            background-color: #000;
            padding-top: 56.25%; /* 16:9 aspect ratio for responsiveness */
            overflow: hidden;
        }
        .image-container img {
            position: absolute;
            top: 0;
            left: 0;
            width: 100%;
            height: 100%;
            object-fit: cover;
            opacity: 0.8; /* Adjust opacity for overlay effect */
        }
        .overlay-text {
            position: absolute;
            top: 50%;
            left: 50%;
            transform: translate(-50%, -50%);
            color: white;
            text-align: none;
            z-index: 10;
        }
        .overlay-text h1 {
            font-size: 2.5em;
            margin-bottom: 10px;
            text-shadow: 2px 2px 4px #000;
        }
        .course-name {
            padding: 15px;
            text-align: center;
            background-color: rgb(44, 235, 177);
            color: #000;
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="image-container">
            <img src="wepw.png">
            <div class="overlay-text">
               <h1>WEB DEVELOPMENT</h1>
            </div>
        </div>
        <div class="course-name">
            Course Name: PW Skills web development
        </div>
    </div>
</body>
</html>

<!--after hover-->

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Web Development Course</title>
    <style>

        body {
            font-family: sans-serif;
            margin: 0;
            padding: 0;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh;
            background-color: #f0f0f0;
        }
        .container {
            background-color: #e0d7d7;
            border-radius: 20px;
            box-shadow: 0 10px 10px rgba(0,0,0,0.1);
            overflow: hidden;
            width: 80%;
            max-width: 700px;
        }
        .image-container {
            position: relative;
            background-color: #000;
            padding-top: 56.25%; /* 16:9 aspect ratio for responsiveness */
            overflow: hidden;
        }
        .image-container img {
            position: absolute;
            top: 0;
            left: 0;
            width: 100%;
            height: 100%;
            object-fit: cover;
            opacity: 0.8; /* Adjust opacity for overlay effect */
        }
        .image-container:hover{
            backdrop-filter: blur(20px);
        }
        .overlay-text {
            position: absolute;
            top: 50%;
            left: 50%;
            transform: translate(-50%, -50%);
            color: white;
            text-align: none;
            z-index: 10;
        }
        .overlay-text h1 {
            font-size: 2.5em;
            margin-bottom: 10px;
            text-shadow: 2px 2px 4px #000;
        }
        .course-name {
            padding: 15px;
            text-align: center;
            background-color: rgb(44, 235, 177);
            color: #000;
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="image-container">
            <img src="wepw.png">
            <div class="overlay-text">
               <h1>WEB DEVELOPMENT</h1>
            </div>
        </div>
        <div class="course-name">
            Course Name: PW Skills web development
        </div>
    </div>
</body>
</html>

# %% [markdown]
# 8. create a simple list of items as mentioned in the below image.
#
# ![image.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Requirements</h1>
    <ol>
        <b>
        <li type="i">System with minimum i3 processor or better.</li>
        <li type="i">At least 4GB of RAM.</li>
        <li type="i">Working inernet connection.</li>
        <li type="i">Dedication to learn.</li>
        </b>
    </ol>
</body>
</html>
