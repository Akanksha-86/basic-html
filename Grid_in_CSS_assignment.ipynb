# %% [markdown]
# # Grid in CSS

# %% [markdown]
# 1. create an image galery using a CSS grid.
#
# ![image.png](data:image/png;base64,...)

# %%
HTML------------
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Colored Rectangles Layout</title>
    <link rel="stylesheet" href="style.css">
</head>
<body>
    <div class="container">
      <div class="image">
         <div class="row top-row">
             <div class="image1">
                <img src="https://png.pngtree.com/thumb_back/fw800/background/20230514/pngtree-beautiful-nature-background-green-grass-flower-with-water-canal-image_2598168.jpg"/>
              </div>
              <div class="image2">
                  <img src="https://5.imimg.com/data5/SELLER/Default/2022/6/FR/KB/HI/92041043/nature-wallpaper.jpeg"/>
                </div>
          </div>
         <div class="row bottom-row">
             <div class="image3"><img src="https://tse1.mm.bing.net/th/id/OIP.S-IYiZM4VKU20ZoZZJmuBQHaEJ?pid=Api&P=0&h=180"/>
             </div>
             <div class="image4"><img src="https://png.pngtree.com/background/20230426/original/pngtree-deer-in-the-forest-at-night-picture-image_2491952.jpg"/>
             </div>
             <div class="image5"><img src="https://www.creativefabrica.com/wp-content/uploads/2022/12/02/Ai-Autumn-Jungle-Deer-Far-Off-Realistic-Fine-Art-Format-49949843-1.png"/>
             </div>
             <div class="image6"><img src="https://tse4.mm.bing.net/th/id/OIP.Y0pkUIq8i8F80BBMxa8negHaE7?pid=Api&P=0&h=180"/>
             </div>
          </div>
        </div>
    </div>

</body>
</html>

CSS-----------

.grid-container {
  display: grid;
  /* Define the grid columns and rows based on the image layout */
  grid-template-columns: 1fr 1fr 1fr; /* Example: three equal columns */
  grid-template-rows: 1fr 1fr 1fr; /* Example: three equal rows */
  gap: 5px; /* Adjust as needed for spacing between items */
  width: 100%; /* Or a specific width */
  height: 400px; /* Or a specific height */
}

.image{
  /* Basic styling for all grid items */
  display: flex;
  justify-content: center;
  align-items: center;
  color: white; /* Text color if any */
}

/* Specific styling for each colored item to match the layout in the image */
.image1 {
  background-color: black;
  grid-column: 1 / span 2; /* Spans across the first two columns */
}

.image2 {
  background-color: blue;
  grid-column: 3 / span 1; /* Occupies the third column */
}

.image3 {
  background-color: cyan;
  grid-row: 2 / span 2; /* Spans across the second and third rows */
  grid-column: 1 / span 1; /* Occupies the first column */
}

.image4 {
  background-color: pink;
  grid-column: 2 / span 1; /* Occupies the second column */
  grid-row: 2 / span 1; /* Occupies the second row */
}

.image5 {
  background-color: green;
  grid-column: 3 / span 1; /* Occupies the third column */
  grid-row: 2 / span 2; /* Spans across the second and third rows */
}

.image6 {
  background-color: yellow;
  grid-column: 2 / span 1; /* Occupies the second column */
  grid-row: 3 / span 1; /* Occupies the third row */
}

# %% [markdown]
# 2. write a code to arrange container with texts A, B, C, and D as shown in the below image.
#
# ![image.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html>
<head>
<title>Expected Output Layout</title>
<style>
  body {
    font-family: sans-serif;
    display: flex;
    justify-content: center;
    align-items: center;
    min-height: 100vh;
    margin: 0;
    background-color: #f0f0f0;
  }
  .container {
    display: flex;
    border: 1px solid black;
    padding: 10px;
    background-color: white;
  }
  .left-column {
    display: flex;
    flex-direction: column;
    margin-right: 10px;
  }
  .right-column {
    display: flex;
    align-items: center; /* Center B vertically if needed */
  }
  .box {
    background-color: #ffe0b2; /* Light orange color */
    display: flex;
    justify-content: center;
    align-items: center;
    margin-bottom: 10px; /* Space between A and C/D */
    color: #333;
    font-weight: bold;
  }
  .box:last-child {
    margin-bottom: 0; /* No margin for the last box in a column */
  }
  .box-a {
    width: 200px;
    height: 80px;
  }
  .box-b {
    width: 100px;
    height: 180px; /* Sum of A, C, D heights approximately */
  }
  .box-c, .box-d {
    width: 95px; /* Slightly less than half of A's width, accounting for margin */
    height: 80px;
  }
  .bottom-row {
    display: flex;
    gap: 10px; /* Space between C and D */
  }
</style>
</head>
<body>

<div class="container">
  <div class="left-column">
    <div class="box box-a">A</div>
    <div class="bottom-row">
      <div class="box box-c">C</div>
      <div class="box box-d">D</div>
    </div>
  </div>
  <div class="right-column">
    <div class="box box-b">B</div>
  </div>
</div>

</body>
</html>

# %% [markdown]
# 3. expain the use of grid-auto-column using code example.
#
#    - The grid-auto-columns CSS property specifies the size of implicitly-created grid columns using values like auto, lengths, percentages, minmax(), and more, ensuring flexible and controlled grid column sizing.

# %%
<!DOCTYPE html>
<html>

<head>
    <title>
        CSS grid-auto-column Property
    </title>

    <style>
        .main {
            display: grid;
            grid-template-areas: "a a";
            grid-gap: 20px;
            padding: 30px;
            background-color: green;
            grid-auto-columns: auto;

        }

        .GFG {
            text-align: center;
            font-size: 35px;
            background-color: white;
            padding: 20px 0;
        }
    </style>
</head>

<body>
    <div class="main">
        <div class="GFG">1</div>
        <div class="GFG">2</div>
        <div class="GFG">3</div>
        <div class="GFG">4</div>
        <div class="GFG">5</div>
    </div>
</body>

</html>

# %% [markdown]
# 4. write CSS to show numbers as shown in the figure, without altering the html code.
# ![image.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
       #container {
            display: grid;
            padding: 5px;
            border: 2px solid black;
            grid-template-columns: 50px 50px 50px 50px 50px 10px;
            border-radius: 10px;

           }
           .container {
    display: flex;
    flex-wrap: wrap;
    gap: 10px;
}

.box {
    width: calc(25% - 10px);
    padding: 20px;
    border-radius: 5px;
    text-align: center;
    color: white;
}


.box1, .box2 {
    order: 2;
}

.box3, .box4, .box5, .box6, .box7, .box8 {
    order: 1;
}


.box1, .box3, .box5, .box7 {
    background-color: #333;
}

.box2, .box4, .box6, .box8 {
    background-color: #aaa;
}

    </style>
</head>
<body>
    <div id="container">
         <div class="box box1">1</div>
         <div class="box box2">2</div>
         <div class="box box3">3</div>
         <div class="box box4">4</div>
         <div class="box box5">5</div>
         <div class="box box6">6</div>
         <div class="box box7">7</div>
         <div class="box box8">8</div>

        </div>
</body>
</html>

# %% [markdown]
# 5. explain the difference between justify-items and justify-self using code example.
#  - The justify-items property is set on the grid container to give child elements (grid items) alignment in the inline direction.

# %%
<!DOCTYPE html>
<html>
<head>
<style>
#container {
  width: 80%;
  aspect-ratio: 4/1;
  border: 1px solid #000000;
  display: grid;
  grid-template-columns: 1fr 1fr 1fr;
  justify-items: space-around;
}

#container div {
  width: 50%;
  aspect-ratio: 1;
}
</style>
</head>
<body>

<h1>Change justify-items with JavaScript</h1>

<div id="container">
  <div style="background-color:coral;"></div>
  <div style="background-color:lightblue;"></div>
  <div style="background-color:pink;"></div>
</div>

<p>Click the "Try it" button to set the value of the justifyItems property to "center". This makes grid items align center within their own grid cell.</p>

<button onclick="myFunction()">Try it</button>

<script>
function myFunction() {
  document.getElementById("container").style.justifyItems = "center";
}
</script>

</body>
</html>

# %% [markdown]
# **justify-self** The justify-self property aligns a grid item within its grid cell in the inline direction

# %%
<!DOCTYPE html>
<html>
<head>
<style>
#container {
  width: 80%;
  aspect-ratio: 4/1;
  border: 1px solid #000000;
  display: grid;
  grid-template-columns: 1fr 1fr 1fr;
}

#container div {
  width: 50%;
  aspect-ratio: 1;
}
</style>
</head>
<body>

<h1>Change justify-self with JavaScript</h1>

<div id="container">
  <div style="background-color:coral;"></div>
  <div id="blue" style="background-color:lightblue;"></div>
  <div style="background-color:pink;"></div>
</div>

<p>Click the "Try it" button to set the value of the justifySelf property to "right". This makes the blue grid item align right within its own grid cell.</p>

<button onclick="myFunction()">Try it</button>

<script>
function myFunction() {
  document.getElementById("blue").style.justifySelf = "right";
}
</script>

</body>
</html>
