# %% [markdown]
# #Core HTML

# %%
# @title Default title text
1. Build a simple webpage that display text as a shown in the image
    <b>this text will be bold</B>
    <i>this text will be italic</i>
    <ins>this text will be underline</ins>
    <mark>this text will be highlight</mark>
    this is normal text<sup>this will be super scripted</sup> this is normal again
    this is normal text <sub>this text will be subscripted</sub>
    normal text <small> smal text</small>
    <del>this text will be deleted</del>

       answer- <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> simple webpage</title>
</head>
<body>
    <b>this text will be bold</B>
        <br>
        <br>

    <i>this text will be italic</i>
    <br>
    <br>
    <ins>this text will be underline</ins>
    <br>
    <br>
    <mark>this text will be highlight</mark>
    <br>
    <br>
    this is normal text<sup>this will be super scripted</sup> this is normal again
    <br>
    <br>
    this is normal text <sub>this text will be subscripted</sub>
    <br>
    <br>
    normal text <small> smal text</small>
    <br>
    <br>
    <del>this text will be deleted</del>
     <br>
</body>
</html>

2. Build a simple webpage the helps users nevigate different web development related websites.
 note:on clicking the hyperlink the weboage open should a new tab.below is a reference image.
  <h1><strong> Nevigate me:</strong></h1>
  Take me to <a href="https//www.pwskills.com/" target="  "> pw skills</a> to buy a course
  Take me to<a href="https//www.mdn docs.com/" target="   "> MDN docs </a> to know more about web development
  Take me to <a href="https//www.pwskills lab.com/" target-"  "> Pwskills lab </a> to practice live coding

  Answer- <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> simple webpage</title>
</head>
<body>
    <h1><strong> Nevigate me:</strong></h1>
Take me to <a href="https//www.pwskills.com/" target="  "> pw skills</a> to buy a course
<br>
<br>
 Take me to<a href="https//www.mdn docs.com/" target="   "> MDN docs </a> to know more about web development
<br>
<br>
 Take me to <a href="https//www.pwskills lab.com/" target-"  "> Pwskills lab </a> to practice live coding
</body>
</html>

3. Build a simple blog webpage with three pages home, web development, and web design, each page must contain hyperlinks to other pages in the top,
a heading of the page topic and a paragraph of information. for the home page you can add some informaion about yourself.

  Answer- Index.HTML
<!DOCTYPE html>
<html>
<head>
<title> Home </title>
</head>
<body>

<nav>
<ul>
<li><a href="index.html">Home</a></li>
<li><a href="web_development.html">Web Development</a></li>
<li><a href="website_design.html">Website Design</a></li>
</ul>
</nav>

<h1>Welcome to the Bulldog Blog!</h1>

<p>This is a simple blog showcasing topics like web development and website design, with a bulldog theme. I'm [akanksha], a web developer passionate about creating clean and user-friendly websites.</p>

</body>
</html>

web development.html
<!DOCTYPE html>
<html>
<head>
<title> Web Development</title>
</head>
<body>

<nav>
<ul>
<li><a href="index.html">Home</a></li>
<li><a href="web_development.html">Web Development</a></li>
<li><a href="website_design.html">Website Design</a></li>
</ul>
</nav>

<h1>Web Development</h1>

<p>Learn the basics of web development.  This section covers fundamental skills like HTML, CSS, and JavaScript. We'll also explore more advanced topics like backend languages and frameworks.</p>

</body>
</html>

website design.html
<!DOCTYPE html>
<html>
<head>
<title>Website Design</title>
</head>
<body>

<nav>
<ul>
<li><a href="index.html">Home</a></li>
<li><a href="web_development.html">Web Development</a></li>
<li><a href="website_design.html">Website Design</a></li>
</ul>
</nav>

<h1>Website Design</h1>

<p>Website design is about creating a user-friendly and visually appealing website. This section covers layout, color schemes, typography, and more.  We'll focus on making websites intuitive and engaging.</p>

</body>
</html>

4. create a order list of HTML tags. each list must including the tag name and some information about the tag.
  Answer -
  <ol>
  <li>
    &lt;html&gt;: This tag is the root element of an HTML page.
  </li>
  <li>
    &lt;head&gt;: This tag contains meta-information about the HTML document, such as the title, links to stylesheets, and scripts.
  </li>
  <li>
    &lt;title&gt;: This tag specifies a title for the HTML page, which is shown in the browser's title bar or page tab.
  </li>
  <li>
     &lt;body&gt;: This tag contains the visible content of the HTML page.
  </li>
  <li>
    &lt;h1&gt; to &lt;h6&gt;: These tags define HTML headings, with &lt;h1&gt; being the most important and &lt;h6&gt; being the least.
  </li>
  <li>
    &lt;p&gt;: This tag defines a paragraph.
  </li>
  <li>
    &lt;a&gt;: This tag creates a hyperlink to other web pages or files.
  </li>
  <li>
     &lt;img&gt;: This tag embeds an image in the HTML page.
  </li>
    <li>
    &lt;ul&gt;: This tag creates an unordered list.
  </li>
  <li>
    &lt;ol&gt;: This tag creates an ordered list.
  </li>
   <li>
    &lt;li&gt;: This tag represents a list item in an ordered or unordered list.
  </li>
  <li>
    &lt;div&gt;: This tag is a container for HTML elements, often used for structuring layout.
  </li>
  <li>
    &lt;span&gt;: This tag is an inline container for HTML elements, often used for styling text.
  </li>
    <li>
    &lt;form&gt;: This tag creates an HTML form for user input.
  </li>
   <li>
    &lt;input&gt;: This tag is used within a form to collect user input.
  </li>
  <li>
    &lt;button&gt;: This tag creates a clickable button.
  </li>
  <li>
    &lt;table&gt;: This tag creates a table.
  </li>
  <li>
    &lt;tr&gt;: This tag defines a row in a table.
  </li>
  <li>
    &lt;th&aspect&gt;: This tag defines a header cell in a table.
  </li>
  <li>
    &lt;td&gt;: This tag defines a data cell in a table.
  </li>
</ol>

5. create a description list a full stack web development tech stack, using the <dl> tag. each term should be a tech stack name and each description should be a brief explaination of what the tech stack is used for.
 Answer -
 <!DOCTYPE html>
<html>
<head>
<title>Full Stack Tech Stack</title>
</head>
<body>

<dl>
  <dt>Frontend</dt>
    <dd>Handles the user interface and user experience.</dd>
  <dt>Backend</dt>
    <dd>Manages the server-side logic and database interactions.</dd>
  <dt>Database</dt>
    <dd>Stores and retrieves data for the application.</dd>
  <dt>DevOps</dt>
    <dd>Focuses on deployment and infrastructure management.</dd>
</dl>

</body>
</html>

# %% [markdown]
# 6. create an ordered list of the full stack web development tech stack HTML, CSS, and JS. for each tech stack, create a table that list the tech stack name. its primary use cases, and some key feature or benefits. below is a refrence image.
# ![Screenshot 2025-06-02 184428.png](data:image/png;base64,...)

# %%
Answer -
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <table border="1" cellspacing="1" cellpadding="10">
    <h1><strong>1. HTML</strong></h1>
    <tr>
<th>primary use cases</th>
<th>key features/benifits </th>
</tr>
<tr>
    <td rowspan="3">Building the structure of web page</td>
    </tr>
    <ul style="circle">
    <tr><td> <li>simple and easy to learn</li>
        <li> compatible with all web browser</li>
        <li> for semantic markup</li>
</td>
    </tr>
    </ul>
</table>
<h1><strong>2. CSS</strong></h1>
<table border="1" cellspacing="1" cellpadding="10">
    <tr>
    <th>primary use cases</th>
    <th>key features/benifits </th>
    </tr>
    <tr>
        <td rowspan="3">styling and layout of the webpage</td>
    </tr>
    <ul style="circle">
       <tr><td><li> Allows for sepration of content and presentation</li>
        <li>Enable responsive design </li>
        <li> Offer a wide range styling option</li>
   </td>
    </tr> </ul>
</table>
<h1><strong>3. JS</strong></h1>
<table border="1" cellspacing="1" cellpadding="10">
    <tr>
    <th>primary use cases</th>
    <th>key features/benifits </th>
    </tr>
    <tr>
        <td rowspan="3">Create dynamic content for webpage</td>
    </tr>
      <ul style="circle"> <tr>
       <td> <li> Easy to learn and implement</li>
        <li> Client- side security</li>
            <li>Rich interfaces</li>
       </td>
    </tr> </ul>
</table>
</body>
</html>

# %% [markdown]
# 7. Build a comlex nested list structure representing a multi-level table contents. use unordered list (<ul>) and list items (<li>) with inline-block styling to createb a structured layout. apply formatting tags to enhence the presentation of list items.
#
# output should look like this
#
# ![Screenshot 2025-06-02 184244.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Table of Contents</title>
</head>
<body>

    <h1>Table of Contents</h1>
    <font color="blue">

    <ul>
        <li>Part 1: Introduction</li>
        <li>Part 2: Getting Started
            <ul>
                <li>2.1 Installing the Software</li>
                <li>2.2 Creating a New Project
                    <ul>
                        <li>2.2.1 Project Templates</li>
                        <li>2.2.2 Customizing Settings</li>
                    </ul>
                </li>
                <li>2.3 Exploring the Interface
                    <ul>
                        <li>2.3.1 Toolbar Features</li>
                        <li>2.3.2 Panel Layout
                            <ul>
                                <li>2.3.2.1 Docking Panels</li>
                                <li>2.3.2.2 Tabbed Interface</li>
                            </ul>
                        </li>
                    </ul>
                </li>
            </ul>
        </li>
        <li>Part 3: Advanced Topics
            <ul>
                <li>3.1 Working with Plugins
                    <ul>
                        <li>3.1.1 Installing Plugins</li>
                        <li>3.1.2 Plugin Configuration</li>
                    </ul>
                </li>
                <li>3.2 Customizing the UI
                    <ul>
                        <li>3.2.1 Changing Themes</li>
                        <li>3.2.2 Configuring Shortcuts</li>
                    </ul>
                </li>
                <li>3.3 Optimizing Performance
                    <ul>
                        <li>3.3.1 Caching Strategies</li>
                        <li>3.3.2 Resource Minification</li>
                    </ul>
                </li>
            </ul>
        </li>
        <li>Part 4: Conclusion</li>
    </ul>
    </font>

</body>
</html>

# %% [markdown]
# 8. ctreate a table to display a conference schdule. each row corresponds to a time slot, and each column corresponds to a room. some time slots might have multiple sessions running simultaneously in different rooms. utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.(use table attribte "cellpadding" to give extra padding in each table cell).
# output should look like this:
# ![Screenshot 2025-06-02 183046.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html>
<head>
<title>Conference Schedule</title>
</head>
<body>

<table cellpadding="10" border="1">
  <caption><b>Conference Schedule</b></caption>
  <thead>
    <tr>
      <th>Time</th>
      <th>Room 1</th>
      <th>Room 2</th>
      <th>Room 3</th>
      <th>Room 4</th>
    </tr>
  </thead>
  <tbody>
    <tr>
      <td>9:00 AM - 10:00 AM</td>
      <td>Keynote</td>
      <td>Session A</td>
      <td>Session B</td>
      <td rowspan="2">Session C</td>
    </tr>
    <tr>
      <td></td>
      <td></td>
      <td>Session D</td>
      <td>Session E</td>
    </tr>
    <tr>
      <td>10:30 AM - 11:30 AM</td>
      <td colspan="2"></td>
      <td>Session F</td>
      <td></td>
    </tr>
    <tr>
        <td>12:00 PM - 1:00 PM</td>
        <td colspan="4">Lunch Break</td>
      </tr>
    <tr>
      <td>1:00 PM - 2:00 PM</td>
      <td>Session G</td>
      <td>Session H</td>
      <td>Session I</td>
      <td>Session J</td>
    </tr>
    <tr>
      <td></td>
      <td>Session K</td>
      <td></td>
      <td>Session L</td>
      <td>Session M</td>
    </tr>
  </tbody>
</table>

</body>
</html>
